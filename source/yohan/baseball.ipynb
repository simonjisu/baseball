# %%
# Date 함수 사용

import urllib
import json
import datetime as dt
import time

# %%
def date_count(interval):
    date_list = []
    for i in range(interval):
        yesterday = dt.datetime.now() - dt.timedelta(days=i+1)
        date_list.append(yesterday.strftime('%Y%m%d'))
        
    return date_list

# %%
#urls = urls + date_count(5)[2]
urls = "http://score.sports.media.daum.net/planus/do/v2/api/sports_games.json?category=kbo&date="
urls += date_count(5)[3]
print(urls)
# JSON 다운로드


# 다운로드 받은 JSON 을 변수에 저장
highlist_json = json.load(urllib.urlopen(urls))
# Out:
# http://score.sports.media.daum.net/planus/do/v2/api/sports_games.json?category=kbo&date=20170623

# %%
castlist_id = []
for i in range(len(highlist_json)):
    castlist_id.append(highlist_json[i]['cp_game_id'])

# %%
castlist_id
# Out:
# [u'20170623LTOB0|2017',
#  u'20170623LGWO0|2017',
#  u'20170623KTSK0|2017',
#  u'20170623HTNC0|2017',
#  u'20170623HHSS0|2017']

# %%
cast_url = "http://data.cast.sports.media.daum.net/bs/kbo/"

# %%
#print(cast_url + castlist_id[0] + cast_url_parameter)
cast_json = json.load(urllib.urlopen(cast_url + castlist_id[0]))

# %%
len(cast_json['livetext'])
# Out:
# 519

# %%
import sqlalchemy
engine = sqlalchemy.create_engine('postgresql://postgres:1234@localhost:5432/baseball', echo=True)

# %%
engine = sqlalchemy.create_engine('postgresql://postgres:1234@localhost:5432/baseball')

# %%
engine
# Out:
# Engine(postgresql://postgres:***@localhost:5432/baseball)

# %%
engine.connect()

# %%
engine.table_names()
# Out:
# [u'livetext',
#  u'team',
#  u'team_season',
#  u'player',
#  u'batter_stats',
#  u'player_profile',
#  u'pitcher_stats']

# %%
from sqlalchemy.ext.declarative import declarative_base

Base = declarative_base()

from sqlalchemy import Column, Integer, String
class User(Base):
    __tablename__ = 'users'

    id = Column(Integer, primary_key=True)
    name = Column(String)
    fullname = Column(String)
    password = Column(String)

    def __repr__(self):
        return "<User(name='%s', fullname='%s', password='%s')>" % (self.name, self.fullname, self.password)

# %%
Base.metadata.create_all(engine)

# %%
from sqlalchemy.orm import sessionmaker

yohanuser = User(name="Yohan", fullname="Yohan Park", password="1234")
asdfuser = User(name="asdf", fullname="asdf qwer", password="23445")

Session = sessionmaker()
Session.configure(bind=engine)  # once engine is available
session = Session()
session.add_all([yohanuser, asdfuser])
session.commit()

# %%
for name, in session.query(User.name).filter_by(fullname='Yohan Park'):
    print(name)
# Out:
# Yohan
# Yohan
# Yohan
# Yohan
# Yohan
# Yohan
# Yohan
# Yohan
# Yohan
# Yohan
# Yohan
# Yohan
# Yohan

# %%
for user in session.query(User).filter(User.name=='Yohan').filter(User.password=='1234'):
    print(user)
# Out:
# <User(name='Yohan', fullname='Yohan Park', password='1234')>
# <User(name='Yohan', fullname='Yohan Park', password='1234')>
# <User(name='Yohan', fullname='Yohan Park', password='1234')>
# <User(name='Yohan', fullname='Yohan Park', password='1234')>
# <User(name='Yohan', fullname='Yohan Park', password='1234')>
# <User(name='Yohan', fullname='Yohan Park', password='1234')>
# <User(name='Yohan', fullname='Yohan Park', password='1234')>
# <User(name='Yohan', fullname='Yohan Park', password='1234')>
# <User(name='Yohan', fullname='Yohan Park', password='1234')>
# <User(name='Yohan', fullname='Yohan Park', password='1234')>

# %%
from sqlalchemy.ext.declarative import declarative_base

Base = declarative_base()

from sqlalchemy import Column, Integer, String
class Livetext(Base):
    __tablename__ = 'livetext'

    id = Column(Integer, primary_key=True)
    batorder = Column(String)
    batter = Column(String)
    btop = Column(String)
    inning = Column(String)
    pitcher = Column(String)
    text = Column(String)
    textstyle = Column(String)

    def __repr__(self):
        return "Done"

# %%
Base.metadata.create_all(engine)

# %%
cast_json['livetext'][0]['batter']

# %%
from sqlalchemy.orm import sessionmaker

texts = []

for i in range(len(cast_json['livetext'])):
    txt = cast_json['livetext'][i]
    texts.append(Livetext(batorder=txt['batorder'],
                          batter=txt['batter'],
                          btop=txt['btop'],
                          inning=txt['inning'],
                          pitcher=txt['pitcher'],
                          text=txt['text'],
                          textstyle=txt['textstyle']))

Session = sessionmaker()
Session.configure(bind=engine)  # once engine is available
session = Session()
session.add_all(texts)
session.commit()

# %%
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()
from sqlalchemy import Column, Integer, String, ForeignKey, DateTime, Float
from sqlalchemy.orm import relationship

class Team(Base):
    __tablename__ = 'team'
    tcode = Column(String, primary_key=True)
    
class Team_season(Base):
    __tablename__ = 'team_season'
    idx = Column(Integer, primary_key=True)
    ab = Column(Float)
    bb = Column(Float)
    bra = Column(Float)
    dra = Column(Float)
    er = Column(Float)
    
    era = Column(Float)
    err = Column(Float)
    game = Column(Float)
    h2 = Column(Float)
    h3 = Column(Float)
    
    hit = Column(Float)
    hp = Column(Float)
    hr = Column(Float)
    hra = Column(Float)
    lose = Column(Float)
    
    lra = Column(Float)
    r = Column(Float)
    rank = Column(Float)
    run = Column(Float)
    same = Column(Float)
    
    sb = Column(Float)
    sf = Column(Float)
    win = Column(Float)
    wra = Column(Float)
    
    dates = Column(DateTime)
    f_name = Column(String)
    tcode = Column(String, ForeignKey('team.tcode'))
    

class Player(Base):
    __tablename__ = 'player'
    player_id = Column(Integer, primary_key=True)
    tcode = Column(String, ForeignKey('team.tcode'))
    
class Player_profile(Base):
    __tablename__ = 'player_profile'
    profile_id = Column(Integer, primary_key=True)
    player_id = Column(Integer, ForeignKey('player.player_id'))
    backnum = Column(Integer)
    bat = Column(String)
    height = Column(Integer)
    name = Column(String)
    position = Column(String)
    throw = Column(String)
    weight = Column(Integer)
    dates = Column(DateTime)
    
class Pitcher_stats(Base):
    __tablename__ = 'pitcher_stats'
    pitcher_id = Column(Integer, primary_key=True)
    profile_id = Column(Integer, ForeignKey('player_profile.profile_id'))
    s_era = Column(Float)
    s_gyear = Column(Float)
    s_hit = Column(Float)
    s_hld = Column(Float)
    s_hr = Column(Float)
    s_kk = Column(Float)
    s_lose = Column(Float)
    s_save = Column(Float)
    s_total_era = Column(Float)
    s_win = Column(Float)
    t_b = Column(Float)
    t_bb = Column(Float)
    t_er = Column(Float)
    t_era = Column(Float)
    t_hbp = Column(Float)
    t_hit = Column(Float)
    t_hr = Column(Float)
    t_ip = Column(Float)
    t_np = Column(Float)
    t_r = Column(Float)
    t_s = Column(Float)
    t_so = Column(Float)
    
class Batter_stats(Base):
    __tablename__ = 'batter_stats'
    batter_id = Column(Integer, primary_key=True)
    profile_id = Column(Integer, ForeignKey('player_profile.profile_id'))
    h_1 = Column(Float)
    h_2 = Column(Float)
    h_3 = Column(Float)
    h_4 = Column(Float)
    h_5 = Column(Float)
    h_6 = Column(Float)
    h_7 = Column(Float)
    h_8 = Column(Float)
    h_9 = Column(Float)
    h_10 = Column(Float)
    h_11 = Column(Float)
    h_12 = Column(Float)
    h_13 = Column(Float)
    s_ab = Column(Float)
    s_avg = Column(Float)
    s_bbhp = Column(Float)
    s_cs = Column(Float)
    s_game = Column(Float)
    s_h2 = Column(Float)
    s_h3 = Column(Float)
    s_hit = Column(Float)
    s_hr = Column(Float)
    s_kk = Column(Float)
    s_rbi = Column(Float)
    s_run = Column(Float)
    s_sb = Column(Float)
    s_shf = Column(Float)
    t_ab = Column(Float)
    t_avg = Column(Float)
    t_bb = Column(Float)
    t_bbhp = Column(Float)
    t_h = Column(Float)
    t_hr = Column(Float)
    t_pa = Column(Float)
    t_r = Column(Float)
    t_rbi = Column(Float)
    t_sb = Column(Float)
    t_so = Column(Float)
    
Base.metadata.create_all(engine)

# %% [markdown]
# # 먼저 team 테이블에 tcode 수동으로 집어넣기 from JSON

# %%
cast_json
# Out:
# {u'game_code': u'20170623LTOB0|2017',
#  u'league': {u'today_games': [u'20170623HHSS0|2017',
#    u'20170623HTNC0|2017',
#    u'20170623KTSK0|2017',
#    u'20170623LGWO0|2017']},
#  u'livetext': [{u'batorder': 0,
#    u'batter': None,
#    u'btop': u'T',
#    u'inning': u'1',
#    u'pitcher': None,
#    u'seq': 0,
#    u'text': u'1\ud68c\ucd08 \ub86f\ub370 \uacf5\uaca9',
#    u'textstyle': 0},
#   {u'batorder': 1,
#    u'batter': u'78513',
#    u'btop': u'T',
#    u'inning': u'1',
#    u'pitcher': u'74513',
#    u'seq': 1,
#    u'text': u'1\ubc88\ud0c0\uc790 \uc804\uc900\uc6b0',
#    u'textstyle': 8},
#   {u'batorder': 1,
#    u'batter': u'78513',
#    u'btop': u'T',
#    u'inning': u'1',
#    u'pitcher': u'74513',
#    u'seq': 2,
#    u'text': u'1\uad6c \uc2a4\ud2b8\ub77c\uc774\ud06c',
#    u'textstyle': 1},
#   {u'batorder': 1,
#    u'batter': u'78513',
#    u'btop': u'T',
#    u'inning': u'1',
#    u'pitcher': u'74513',
#    u'seq': 3,
#    u'text': u'2\uad6c \ubcfc',
# ...

# %%
team_list = cast_json['registry']['team']
db_data = []
dicasdf = {}
for i in team_list:
    if 'season' in team_list[i]:
        #team_list.items(i)
        dicasdf = 
        print(team_list[i]['profile']['teamname1'])
# Out:
# NC
# 넥센
# KIA
# 두산
# 한화
# LG
# 롯데
# 삼성
# SK
# kt

# %%
team_list
# Out:
# {u'region': None, u'stadium': None, u'teamname1': u'kt', u'teamname2': u'kt'}

# %%
from sqlalchemy.orm import sessionmaker

team_list = cast_json['registry']['team']
db_data = []

for i in team_list:
    if 'season' in team_list[i]:
        db_data.append(Team_season(f_name=team_list[i]['profile']['teamname1'] + " " + team_list[i]['profile']['teamname2'],
                                  tcode=team_list[i]['season']['team_cd'],
                                  ab=team_list[i]['season']['ab'],
                                  bb=team_list[i]['season']['bb'],
                                  bra=team_list[i]['season']['bra'],
                                  dra=team_list[i]['season']['dra'],
                                  er=team_list[i]['season']['team_cd'],
                                  era=team_list[i]['profile']['era'],
                                  err=team_list[i]['profile']['err'],
                                  game=team_list[i]['profile']['game'],
                                  h2=team_list[i]['profile']['h2'],
                                  h3=team_list[i]['profile']['h3'],
                                  hit=team_list[i]['profile']['hit'],
                                  hp=team_list[i]['profile']['hp'],
                                  hr=team_list[i]['profile']['hr'],
                                  hra=team_list[i]['profile']['hra'],
                                  lose=team_list[i]['profile']['lose'],
                                  lra=team_list[i]['profile']['lra'],
                                  r=team_list[i]['profile']['r'],
                                  rank=team_list[i]['profile']['rank'],
                                  run=team_list[i]['profile']['run'],
                                  same=team_list[i]['profile']['same'],
                                  sb=team_list[i]['profile']['sb'],
                                  sf=team_list[i]['profile']['sf'],
                                  win=team_list[i]['profile']['win'],
                                  wra=team_list[i]['profile']['wra'],
                                  dates=dt.datetime(2017,03,02))
                      )
        print(team_list[i]['profile']['teamname1'])
    
Session = sessionmaker()
Session.configure(bind=engine)  # once engine is available
session = Session()
session.add_all(texts)
session.commit()
# Out:
# KeyErrorTraceback (most recent call last)
# <ipython-input-84-9d9f163964d8> in <module>()
#       6     if 'season' in team_list[i]:
#       7         #team_list.items(i)
# ----> 8         print(team_list[i]['profile']['aa'])
#       9
#      10 Session = sessionmaker()
#
# KeyError: 'aa'

# %%
# team_season 테이블에 데이터 넣기

from sqlalchemy.orm import sessionmaker

datas = {}


team_record = []
for i in team_list :
    team_record.append(cast_json['registry']['team'][i]['season'].values())

team_name = []
for i in team_list :
    team_name.append(cast_json['registry']['team'][i]['profile'].values())

full_name = []
for i in range(len(team_name)) :
    full_name.append(team_name[i][1] + team_name[i][0])
    team_record[i].append(full_name[i])
    team_record[i].append(team_record[i].pop(9))
    
    
texts = []
for i in range(len(team_record)):
    texts.append(Livetext(batorder=txt['batorder'],
                          batter=txt['batter'],
                          btop=txt['btop'],
                          inning=txt['inning'],
                          pitcher=txt['pitcher'],
                          text=txt['text'],
                          textstyle=txt['textstyle']))

Session = sessionmaker()
Session.configure(bind=engine)  # once engine is available
session = Session()
session.add_all(texts)
session.commit()
# Out:
# AttributeErrorTraceback (most recent call last)
# <ipython-input-50-c9e0695aa37e> in <module>()
#      12 cast_json
#      13
# ---> 14 type.cast_json
#
# AttributeError: type object 'type' has no attribute 'cast_json'
